# %%
import pandas as pd

# %%
import numpy as np

# %%
from datetime import datetime

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = [17.5, 5]

# %%
raw_data = pd.read_excel("H://Python_Projects_001//Test_PV//2021 06 26 0000 (Float).xlsx")
raw_data[12:32]
# Out:
#         ;Date      Time  Millitm  \
# 12 2021-06-26  00:00:01      183
# 13 2021-06-26  00:00:01      183
# 14 2021-06-26  00:00:01      183
# 15 2021-06-26  00:00:01      183
# 16 2021-06-26  00:00:01      183
# 17 2021-06-26  00:00:01      183
# 18 2021-06-26  00:00:01      183
# 19 2021-06-26  00:00:01      183
# 20 2021-06-26  00:00:01      183
# 21 2021-06-26  00:00:01      183
# 22 2021-06-26  00:00:01      183
# 23 2021-06-26  00:00:01      183
# 24 2021-06-26  00:00:01      183
# 25 2021-06-26  00:00:01      183
# 26 2021-06-26  00:00:01      183
# 27 2021-06-26  00:00:01      183
# 28 2021-06-26  00:00:01      183
# 29 2021-06-26  00:00:01      183
# 30 2021-06-26  00:00:01      183
# 31 2021-06-26  00:02:04      701
#
#                                               Tagname       Value Status  \
# 12  LOG\INVERTER_2_DC_POWER                       ...    0.000000
# 13  LOG\INVERTER_3_DC_POWER                       ...    0.000000
# 14  LOG\INVERTER_4_AC_POWER                       ...    0.000000
# 15  LOG\INVERTER_4_DC_POWER                       ...    0.000000
# 16  LOG\INVERTER_5_AC_POWER                       ...    0.000000
# 17  LOG\INVERTER_5_DC_POWER                       ...    0.000000
# 18  LOG\PRODUCTTRANSFERTRIP                       ...    0.000000
# 19  LOG\PV_MODULE_TEMPERATURE                     ...   27.400000
# 20  LOG\SOC_BATTERY_CLUSTER_1                     ...   92.000000
# 21  LOG\SOC_BATTERY_CLUSTER_2                     ...   92.000000
# 22  LOG\SOC_BATTERY_MAIN_CLUSTER                  ...   93.000000
# 23  LOG\SOLAR_IRRADIATION                         ...    0.000000
# 24  LOG\TOTAL_POWER                               ...    0.000000
# 25  LOG\VOLTAGE_OF_GRID_PHASE_1                   ...  232.077042
# 26  LOG\VOLTAGE_OF_GRID_PHASE_2                   ...  232.162094
# 27  LOG\VOLTAGE_OF_GRID_PHASE_3                   ...  231.946915
# 28  LOG\WIND_SPEED                                ...    0.000000
# 29  LOG\INVERTER_3_AC_POWER                       ...   55.289047
# 30  LOG\ENERGY_GENERATED                          ...  706.388123
# 31  LOG\AMBIENT_TEMPRATURE                        ...   30.000000
#
#    Marker  Internal
# 12      B        -1
# 13      B        -1
# 14      B        -1
# 15      B        -1
# 16      B        -1
# 17      B        -1
# 18      B        -1
# 19      B        -1
# 20      B        -1
# 21      B        -1
# 22      B        -1
# 23      B        -1
# 24      B        -1
# 25      B        -1
# 26      B        -1
# 27      B        -1
# 28      B        -1
# 29      B        -1
# 30      B        -1
# 31                0

# %%
# Important ----Remove whitspace befor and after string --- here Tagname----
raw_data['Tagname'] = raw_data['Tagname'].str.strip()

# %%
# Time column is in datetime formate to extract one hour time, Time column to be converted to string
raw_data['Time'][1]
# Out:
# datetime.time(0, 0, 1)

# %%
# Converting datetime to string, use strftime('%H:%M:%S')
# ff - In datetime format
# ff1 - Converted to String format
ff = raw_data['Time'][425]
ff1 = ff.strftime('%H:%M:%S')
ff1
# Out:
# '01:02:04'

# %%
ff3 = raw_data['Time']
ff3
# Out:
# 0       00:00:01
# 1       00:00:01
# 2       00:00:01
# 3       00:00:01
# 4       00:00:01
#           ...
# 8985    00:00:00
# 8986    00:00:00
# 8987    00:00:00
# 8988    00:00:00
# 8989    00:00:00
# Name: Time, Length: 8990, dtype: object

# %%
ff4 = pd.to_datetime(ff3,format= '%H:%M:%S')
ff4
# Out:
# 0      1900-01-01 00:00:01
# 1      1900-01-01 00:00:01
# 2      1900-01-01 00:00:01
# 3      1900-01-01 00:00:01
# 4      1900-01-01 00:00:01
#                ...
# 8985   1900-01-01 00:00:00
# 8986   1900-01-01 00:00:00
# 8987   1900-01-01 00:00:00
# 8988   1900-01-01 00:00:00
# 8989   1900-01-01 00:00:00
# Name: Time, Length: 8990, dtype: datetime64[ns]

# %%
Time_hr = ff4.dt.time
Time_hr
# Out:
# 0       00:00:01
# 1       00:00:01
# 2       00:00:01
# 3       00:00:01
# 4       00:00:01
#           ...
# 8985    00:00:00
# 8986    00:00:00
# 8987    00:00:00
# 8988    00:00:00
# 8989    00:00:00
# Name: Time, Length: 8990, dtype: object

# %%
Time_hr_str = ff4.dt.strftime('%H:%M:%S')
Time_hr_str
# Out:
# 0       00:00:01
# 1       00:00:01
# 2       00:00:01
# 3       00:00:01
# 4       00:00:01
#           ...
# 8985    00:00:00
# 8986    00:00:00
# 8987    00:00:00
# 8988    00:00:00
# 8989    00:00:00
# Name: Time, Length: 8990, dtype: object

# %%
rd_df = raw_data.copy()

# %%
rd_df
# Out:
#           ;Date      Time  Millitm                      Tagname         Value  \
# 0    2021-06-26  00:00:01      183       LOG\AMBIENT_TEMPRATURE     30.000000
# 1    2021-06-26  00:00:01      183  LOG\ENERGY_CONSUMED_BY_LOAD    119.779480
# 2    2021-06-26  00:00:01      183   LOG\EVENT_FAULT_INVERTER_1  10863.000000
# 3    2021-06-26  00:00:01      183   LOG\EVENT_FAULT_INVERTER_2      0.000000
# 4    2021-06-26  00:00:01      183   LOG\EVENT_FAULT_INVERTER_3  13007.000000
# ...         ...       ...      ...                          ...           ...
# 8985 2021-06-27  00:00:00      125  LOG\VOLTAGE_OF_GRID_PHASE_2    229.688583
# 8986 2021-06-27  00:00:00      125  LOG\VOLTAGE_OF_GRID_PHASE_3    229.719467
# 8987 2021-06-27  00:00:00      125               LOG\WIND_SPEED      0.000000
# 8988 2021-06-27  00:00:00      125      LOG\INVERTER_3_AC_POWER     55.304024
# 8989 2021-06-27  00:00:00      125         LOG\ENERGY_GENERATED    706.885498
#
#      Status Marker  Internal
# 0                B        -1
# 1                B        -1
# 2                B        -1
# 3                B        -1
# 4                B        -1
# ...     ...    ...       ...
# 8985             E      8954
# 8986             E      8955
# 8987             E      8956
# 8988             E      8957
# 8989             E      8958
#
# [8990 rows x 8 columns]

# %%
rd_df.insert(2, "Time_srt",Time_hr_str )

# %%
rd_df
# Out:
#           ;Date      Time  Time_srt  Millitm                      Tagname  \
# 0    2021-06-26  00:00:01  00:00:01      183       LOG\AMBIENT_TEMPRATURE
# 1    2021-06-26  00:00:01  00:00:01      183  LOG\ENERGY_CONSUMED_BY_LOAD
# 2    2021-06-26  00:00:01  00:00:01      183   LOG\EVENT_FAULT_INVERTER_1
# 3    2021-06-26  00:00:01  00:00:01      183   LOG\EVENT_FAULT_INVERTER_2
# 4    2021-06-26  00:00:01  00:00:01      183   LOG\EVENT_FAULT_INVERTER_3
# ...         ...       ...       ...      ...                          ...
# 8985 2021-06-27  00:00:00  00:00:00      125  LOG\VOLTAGE_OF_GRID_PHASE_2
# 8986 2021-06-27  00:00:00  00:00:00      125  LOG\VOLTAGE_OF_GRID_PHASE_3
# 8987 2021-06-27  00:00:00  00:00:00      125               LOG\WIND_SPEED
# 8988 2021-06-27  00:00:00  00:00:00      125      LOG\INVERTER_3_AC_POWER
# 8989 2021-06-27  00:00:00  00:00:00      125         LOG\ENERGY_GENERATED
#
#              Value Status Marker  Internal
# 0        30.000000             B        -1
# 1       119.779480             B        -1
# 2     10863.000000             B        -1
# 3         0.000000             B        -1
# 4     13007.000000             B        -1
# ...            ...    ...    ...       ...
# 8985    229.688583             E      8954
# 8986    229.719467             E      8955
# 8987      0.000000             E      8956
# 8988     55.304024             E      8957
# 8989    706.885498             E      8958
#
# [8990 rows x 9 columns]

# %%
# Time_hr_str[]

# %%
# raw_data.shape

# %%
# raw_data.index

# %%
# raw_data['Tagname'] == 'LOG\ENERGY_GENERATED'

# %%
# raw_data[raw_data['Tagname'] == 'LOG\ENERGY_GENERATED']

# %%
# raw_data.tail(5)

# %%
# raw_data['Value']

# %%
# filtData = raw_data[raw_data["Tagname"] == 'LOG\ENERGY_GENERATED']

# %%
# filtData

# %%
#  filtData.reset_index(drop=True, inplace=True)

# %%
# filtData

# %%
# time_ts = pd.to_datetime(filtData["Time"].iloc[3], format='%H:%M:%S')

# %%
# time_ts

# %%
# onehr_ts = pd.date_range(time_ts, periods=24, freq='1h')
# onehr1 = onehr_ts.strftime('%H:%M:%S')

# %%
# rd_df[rd_df['Time_srt'] == onehr1[1]]

# %%
# raw_data['Time'][1].

# %%
# ff = raw_data['Time'][425]
# ff1 = ff.strftime('%H:%M:%S')

# %%
# ff1

# %%
# onehr1[1]

# %%
# ff1 == onehr1[1]

# %%
class Extracting_Para ():

    def __init__(self, Tagname):
        self.Tagname = Tagname
        
    def individual_df(self):
        ind_df = pd.DataFrame()
        filtData = rd_df[rd_df["Tagname"] == self.Tagname]
        filtData.reset_index(drop=True, inplace=True)
        time_ts = pd.to_datetime(filtData["Time"].iloc[1], format='%H:%M:%S')
        onehr_ts = pd.date_range(time_ts, periods=24, freq='1h')
        onehr1 = onehr_ts.strftime('%H:%M:%S')
        for x in range(0, len(filtData)):
            for y in onehr1:
                if(filtData["Time_srt"].iloc[x] == y):
                    c1 = filtData["Time_srt"] == y
                    Extract = filtData.loc[c1, [';Date', 'Time_srt', 'Tagname', 'Value']]
                    ind_df = ind_df.append(Extract)
        ind_df.reset_index(drop=True, inplace=True)
        ind_df1 = ind_df.copy()
        self.ind_df1 = ind_df1
        return ind_df

#     def onehr_df(self):
#         val = self.ind_df1
#         val1 = val["Value"]
#         onehr_val = np.diff(val1)*1000
#         onehr_val=np.insert(onehr_val,0,0)
#         val.insert(4, "KW/hr",  onehr_val)
#         return val

    def onehr_df(self):
        val = self.ind_df1
        val1 = val["Value"]
        onehr_val = np.diff(val1)*1000
        cpVal = onehr_val[1]
        onehr_val=np.insert(onehr_val,0,cpVal)
        val.insert(4, "KW/hr",  onehr_val)
        return val
    
    def total(self):
        onedf = self.ind_df1
        totalEg = (onedf.iloc[-1]['Value'] - onedf.iloc[0]['Value'])*1000
        totalVal = f'TOTAL_{self.Tagname[4:]} = {"{:.2f}".format(totalEg)} KW ' 
        return totalVal
#     def stri(self):
#         return self.Tagname[4:]
#     >>> print("{:.2f}".format(a))

# %%
energy_gen = Extracting_Para("LOG\ENERGY_GENERATED")
df_energy_gen = energy_gen.individual_df()
eng_gen_onehr = energy_gen.onehr_df()
Total_gen = energy_gen.total()
# sss = energy_gen.stri()

# %%
Total_gen
# Out:
# 'TOTAL_ENERGY_GENERATED = 497.38 KW '

# %%
df_energy_gen
# Out:
#         ;Date  Time_srt               Tagname       Value
# 0  2021-06-26  00:02:04  LOG\ENERGY_GENERATED  706.388123
# 1  2021-06-26  01:02:04  LOG\ENERGY_GENERATED  706.388123
# 2  2021-06-26  02:02:04  LOG\ENERGY_GENERATED  706.388123
# 3  2021-06-26  03:02:04  LOG\ENERGY_GENERATED  706.388123
# 4  2021-06-26  04:02:04  LOG\ENERGY_GENERATED  706.388123
# 5  2021-06-26  05:02:04  LOG\ENERGY_GENERATED  706.388123
# 6  2021-06-26  06:02:04  LOG\ENERGY_GENERATED  706.388184
# 7  2021-06-26  07:02:04  LOG\ENERGY_GENERATED  706.391296
# 8  2021-06-26  08:02:04  LOG\ENERGY_GENERATED  706.404785
# 9  2021-06-26  09:02:04  LOG\ENERGY_GENERATED  706.434753
# 10 2021-06-26  10:02:04  LOG\ENERGY_GENERATED  706.480347
# 11 2021-06-26  11:02:04  LOG\ENERGY_GENERATED  706.537842
# 12 2021-06-26  12:02:04  LOG\ENERGY_GENERATED  706.601807
# 13 2021-06-26  13:02:04  LOG\ENERGY_GENERATED  706.668152
# 14 2021-06-26  14:02:04  LOG\ENERGY_GENERATED  706.731506
# 15 2021-06-26  15:02:04  LOG\ENERGY_GENERATED  706.787415
# 16 2021-06-26  16:02:04  LOG\ENERGY_GENERATED  706.832581
# 17 2021-06-26  17:02:04  LOG\ENERGY_GENERATED  706.864380
# 18 2021-06-26  18:02:04  LOG\ENERGY_GENERATED  706.880188
# 19 2021-06-26  19:02:04  LOG\ENERGY_GENERATED  706.885193
# 20 2021-06-26  20:02:04  LOG\ENERGY_GENERATED  706.885498
# 21 2021-06-26  21:02:04  LOG\ENERGY_GENERATED  706.885498
# 22 2021-06-26  22:02:04  LOG\ENERGY_GENERATED  706.885498
# 23 2021-06-26  23:02:04  LOG\ENERGY_GENERATED  706.885498

# %%
eng_gen_onehr.head()
# Out:
#        ;Date  Time_srt               Tagname       Value  KW/hr
# 0 2021-06-26  00:02:04  LOG\ENERGY_GENERATED  706.388123    0.0
# 1 2021-06-26  01:02:04  LOG\ENERGY_GENERATED  706.388123    0.0
# 2 2021-06-26  02:02:04  LOG\ENERGY_GENERATED  706.388123    0.0
# 3 2021-06-26  03:02:04  LOG\ENERGY_GENERATED  706.388123    0.0
# 4 2021-06-26  04:02:04  LOG\ENERGY_GENERATED  706.388123    0.0

# %%
(eng_gen_onehr.iloc[-1]['Value'] - eng_gen_onehr.iloc[-0]['Value'])*1000
# Out:
# 497.3754899999676

# %%
sum(eng_gen_onehr["KW/hr"])
# Out:
# 497.3754899999676

# %%
len(eng_gen_onehr)
# Out:
# 24

# %%
energy_exp = Extracting_Para("LOG\EXPORTED_ENERGY_TO_GRID")
df_energy_exp = energy_exp.individual_df()
eng_exp_onehr = energy_exp.onehr_df()
Total_exp = energy_exp.total()

# %%
eng_exp_onehr.head()
# Out:
#        ;Date  Time_srt                      Tagname       Value  KW/hr
# 0 2021-06-26  00:02:04  LOG\EXPORTED_ENERGY_TO_GRID  526.432495    0.0
# 1 2021-06-26  01:02:04  LOG\EXPORTED_ENERGY_TO_GRID  526.432495    0.0
# 2 2021-06-26  02:02:04  LOG\EXPORTED_ENERGY_TO_GRID  526.432495    0.0
# 3 2021-06-26  03:02:04  LOG\EXPORTED_ENERGY_TO_GRID  526.432495    0.0
# 4 2021-06-26  04:02:04  LOG\EXPORTED_ENERGY_TO_GRID  526.432495    0.0

# %%
Total_exp
# Out:
# 'TOTAL_EXPORTED_ENERGY_TO_GRID = 273.19 KW '

# %%
energy_imp = Extracting_Para("LOG\IMPORTED_ENERGY_TO_GRID")
df_energy_imp = energy_imp.individual_df()
energy_imp_onehr = energy_imp.onehr_df()
Total_imp = energy_imp.total()

# %%
energy_imp_onehr.head()
# Out:
#        ;Date  Time_srt                      Tagname     Value    KW/hr
# 0 2021-06-26  00:02:04  LOG\IMPORTED_ENERGY_TO_GRID  7.231189  0.04673
# 1 2021-06-26  01:02:04  LOG\IMPORTED_ENERGY_TO_GRID  7.231241  0.05198
# 2 2021-06-26  02:02:04  LOG\IMPORTED_ENERGY_TO_GRID  7.231288  0.04673
# 3 2021-06-26  03:02:04  LOG\IMPORTED_ENERGY_TO_GRID  7.231341  0.05340
# 4 2021-06-26  04:02:04  LOG\IMPORTED_ENERGY_TO_GRID  7.231390  0.04912

# %%
Total_imp
# Out:
# 'TOTAL_IMPORTED_ENERGY_TO_GRID = 1.32 KW '

# %%
energy_con = Extracting_Para("LOG\ENERGY_CONSUMED_BY_LOAD")
df_energy_con = energy_con.individual_df()
energy_con_onehr = energy_con.onehr_df()
Total_con = energy_con.total()

# %%
energy_con_onehr.head()
# Out:
#        ;Date  Time_srt                      Tagname       Value    KW/hr
# 0 2021-06-26  00:02:04  LOG\ENERGY_CONSUMED_BY_LOAD  119.779480  7.49207
# 1 2021-06-26  01:02:04  LOG\ENERGY_CONSUMED_BY_LOAD  119.786987  7.50732
# 2 2021-06-26  02:02:04  LOG\ENERGY_CONSUMED_BY_LOAD  119.794479  7.49207
# 3 2021-06-26  03:02:04  LOG\ENERGY_CONSUMED_BY_LOAD  119.801987  7.50732
# 4 2021-06-26  04:02:04  LOG\ENERGY_CONSUMED_BY_LOAD  119.809464  7.47681

# %%
Total_con
# Out:
# 'TOTAL_ENERGY_CONSUMED_BY_LOAD = 172.28 KW '

# %%
energy_con_onehr['Time_srt'].head()
# Out:
# 0    00:02:04
# 1    01:02:04
# 2    02:02:04
# 3    03:02:04
# 4    04:02:04
# Name: Time_srt, dtype: object

# %%
amp_temp = Extracting_Para("LOG\AMBIENT_TEMPRATURE")
at = amp_temp.individual_df()
# energy_con_onehr = energy_con.onehr_df()

# %%
at
# Out:
#         ;Date  Time_srt                 Tagname      Value
# 0  2021-06-26  00:02:04  LOG\AMBIENT_TEMPRATURE  30.000000
# 1  2021-06-26  01:02:04  LOG\AMBIENT_TEMPRATURE  29.000000
# 2  2021-06-26  02:02:04  LOG\AMBIENT_TEMPRATURE  28.299999
# 3  2021-06-26  03:02:04  LOG\AMBIENT_TEMPRATURE  27.000000
# 4  2021-06-26  04:02:04  LOG\AMBIENT_TEMPRATURE  27.100000
# 5  2021-06-26  05:02:04  LOG\AMBIENT_TEMPRATURE  25.900000
# 6  2021-06-26  06:02:04  LOG\AMBIENT_TEMPRATURE  26.500000
# 7  2021-06-26  07:02:04  LOG\AMBIENT_TEMPRATURE  32.200001
# 8  2021-06-26  08:02:04  LOG\AMBIENT_TEMPRATURE  35.299999
# 9  2021-06-26  09:02:04  LOG\AMBIENT_TEMPRATURE  37.599998
# 10 2021-06-26  10:02:04  LOG\AMBIENT_TEMPRATURE  38.500000
# 11 2021-06-26  11:02:04  LOG\AMBIENT_TEMPRATURE  41.400002
# 12 2021-06-26  12:02:04  LOG\AMBIENT_TEMPRATURE  41.799999
# 13 2021-06-26  13:02:04  LOG\AMBIENT_TEMPRATURE  42.599998
# 14 2021-06-26  14:02:04  LOG\AMBIENT_TEMPRATURE  43.400002
# 15 2021-06-26  15:02:04  LOG\AMBIENT_TEMPRATURE  44.700001
# 16 2021-06-26  16:02:04  LOG\AMBIENT_TEMPRATURE  44.599998
# 17 2021-06-26  17:02:04  LOG\AMBIENT_TEMPRATURE  42.500000
# 18 2021-06-26  18:02:04  LOG\AMBIENT_TEMPRATURE  41.099998
# 19 2021-06-26  19:02:04  LOG\AMBIENT_TEMPRATURE  39.299999
# 20 2021-06-26  20:02:04  LOG\AMBIENT_TEMPRATURE  37.200001
# 21 2021-06-26  21:02:04  LOG\AMBIENT_TEMPRATURE  34.200001
# 22 2021-06-26  22:02:04  LOG\AMBIENT_TEMPRATURE  33.000000
# 23 2021-06-26  23:02:04  LOG\AMBIENT_TEMPRATURE  31.900000

# %%
s = at['Time_srt']

# %%
ss = s.str.slice(stop = 5)

# %%
ss.head()
# Out:
# 0    00:02
# 1    01:02
# 2    02:02
# 3    03:02
# 4    04:02
# Name: Time_srt, dtype: object

# %%
batt = Extracting_Para("LOG\SOC_BATTERY_MAIN_CLUSTER")
batt_st = batt.individual_df()
# energy_con_onehr = energy_con.onehr_df()
# LOG\SOC_BATTERY_MAIN_CLUSTER

# %%
batt_st
# Out:
#         ;Date  Time_srt                       Tagname  Value
# 0  2021-06-26  00:02:04  LOG\SOC_BATTERY_MAIN_CLUSTER   93.0
# 1  2021-06-26  01:02:04  LOG\SOC_BATTERY_MAIN_CLUSTER   92.0
# 2  2021-06-26  02:02:04  LOG\SOC_BATTERY_MAIN_CLUSTER   90.0
# 3  2021-06-26  03:02:04  LOG\SOC_BATTERY_MAIN_CLUSTER   88.0
# 4  2021-06-26  04:02:04  LOG\SOC_BATTERY_MAIN_CLUSTER   87.0
# 5  2021-06-26  05:02:04  LOG\SOC_BATTERY_MAIN_CLUSTER   85.0
# 6  2021-06-26  06:02:04  LOG\SOC_BATTERY_MAIN_CLUSTER   84.0
# 7  2021-06-26  07:02:04  LOG\SOC_BATTERY_MAIN_CLUSTER   83.0
# 8  2021-06-26  08:02:04  LOG\SOC_BATTERY_MAIN_CLUSTER   84.0
# 9  2021-06-26  09:02:04  LOG\SOC_BATTERY_MAIN_CLUSTER   88.0
# 10 2021-06-26  10:02:04  LOG\SOC_BATTERY_MAIN_CLUSTER   89.0
# 11 2021-06-26  11:02:04  LOG\SOC_BATTERY_MAIN_CLUSTER   91.0
# 12 2021-06-26  12:02:04  LOG\SOC_BATTERY_MAIN_CLUSTER   93.0
# 13 2021-06-26  13:02:04  LOG\SOC_BATTERY_MAIN_CLUSTER   95.0
# 14 2021-06-26  14:02:04  LOG\SOC_BATTERY_MAIN_CLUSTER   97.0
# 15 2021-06-26  15:02:04  LOG\SOC_BATTERY_MAIN_CLUSTER   98.0
# 16 2021-06-26  16:02:04  LOG\SOC_BATTERY_MAIN_CLUSTER  100.0
# 17 2021-06-26  17:02:04  LOG\SOC_BATTERY_MAIN_CLUSTER  100.0
# 18 2021-06-26  18:02:04  LOG\SOC_BATTERY_MAIN_CLUSTER  100.0
# 19 2021-06-26  19:02:04  LOG\SOC_BATTERY_MAIN_CLUSTER   99.0
# 20 2021-06-26  20:02:04  LOG\SOC_BATTERY_MAIN_CLUSTER   98.0
# 21 2021-06-26  21:02:04  LOG\SOC_BATTERY_MAIN_CLUSTER   97.0
# 22 2021-06-26  22:02:04  LOG\SOC_BATTERY_MAIN_CLUSTER   95.0
# 23 2021-06-26  23:02:04  LOG\SOC_BATTERY_MAIN_CLUSTER   94.0

# %%
xec = energy_con_onehr['Time_srt']
yec = energy_con_onehr['KW/hr']
xei = energy_imp_onehr['Time_srt']
yei = energy_imp_onehr['KW/hr']
xeg = eng_gen_onehr['Time_srt']
yeg = eng_gen_onehr['KW/hr']
xee = eng_exp_onehr['Time_srt']
yee = eng_exp_onehr['KW/hr']
xat = at['Time_srt']
yat = at['Value']
ybs = batt_st['Value']

# %%
# plt.plot([0.1, 0.2, 0.3, 0.4], [1, 2, 3, 4])
# plt.plot([0.1, 0.2, 0.3, 0.4], [1, 4, 9, 16])
# plt.xlabel("Time (s)")
# plt.ylabel("Scale (Bananas)")

# %%
xec.to_numpy;
yec.to_numpy;
xeg.to_numpy;
yeg.to_numpy;
xei.to_numpy;
yei.to_numpy;
xee.to_numpy;
yee.to_numpy;
xat.to_numpy;
yat.to_numpy;
ybs.to_numpy;

# %%
rd_df[';Date'][1]
# Out:
# Timestamp('2021-06-26 00:00:00')

# %%
date = rd_df[';Date'][1].date()

# %%
filedate = date.strftime("%Y/%m/%d")

# %%
ss.head()
# Out:
# 0    00:02
# 1    01:02
# 2    02:02
# 3    03:02
# 4    04:02
# Name: Time_srt, dtype: object

# %%
# ax = df.plot(x_compat=True)
plt.plot(ss, yec, label="Energy Consumed")
plt.plot(ss, yeg, label="Energy Generated")
plt.plot(ss, yei, label="Energy Imported")
plt.plot(ss, yee, label="Energy Exported")
plt.plot(ss, yat, label="Ambient Temperature")

plt.plot(ss, ybs, label="Battery Status")

plt.xticks(np.arange(0, len(ss), 1))

# plt.xticks(np.arange(0, len(xeg)+1, 4));
# plt.yticks(np.arange(0, max (yec), 1))
plt.legend();
plt.grid()

# %%
# ax = df.plot(x_compat=True)
# %matplotlib inline
ax = plt.subplot(111)


ax.set_xlabel("Time_srt",fontsize=14)
ax.set_ylabel("KW/hr",color="red",fontsize=14)


l1 = ax.plot(ss, yeg, '-', label="Energy Generated")
l2 = ax.plot(ss, yec,'-', label="Energy Consumed")
l3 = ax.plot(ss, yee, '-', label="Energy Exported")
l4 = ax.plot(ss, yei, '-', label="Energy Imported")
# l5 = ax.plot(ss, yat, '-', label="Ambient Temperature")

ax2=ax.twinx()
l6 = ax2.plot(ss, ybs, '-', label = 'Battery %', color='b');
ax2.set_ylabel("Battery %",color="blue",fontsize=14)

l = l1+l2+l3+l4+l6
labs = [ll.get_label() for ll in l]
ax.legend(l, labs, loc=2);
# plt.xticks(np.arange(0, len(ss), 1))

# plt.xticks(np.arange(0, len(xeg)+1, 4));
# plt.yticks(np.arange(0, max (yec), 1))
# plt.legend();
ax.grid();
plt.title(f'PV Energy Profile for date -{filedate}', fontdict = {'fontsize' : 15},color= 'blue', fontweight='bold')
plt.show();

# %%
# Adding Total value in the Legend - Task completed

ax = plt.subplot(111)

ax.set_xlabel("Time_srt",fontsize=14)
ax.set_ylabel("KW/hr",color="red",fontsize=14)

l1 = ax.plot(ss, yeg, '-', label=f"Energy Generated - {Total_gen}", color='g')
l2 = ax.plot(ss, yec,'-', label=f"Energy Consumed - {Total_con}", color='lime')
l3 = ax.plot(ss, yee, '-', label=f"Energy Exported - {Total_exp}", color='b')
l4 = ax.plot(ss, yei, '-', label=f"Energy Imported - {Total_imp}", color='r')
# l5 = ax.plot(ss, yat, '-', label="Ambient Temperature")

ax2=ax.twinx()
l6 = ax2.plot(ss, ybs, '-', label = 'Battery %', color='darkviolet')
ax2.set_ylabel("Battery %",color="darkviolet",fontsize=14)
ax2.set_ylim([70, 105])

l = l1+l2+l3+l4+l6
labs = [ll.get_label() for ll in l]
ax.legend(l, labs, loc=2);

ax.grid();
plt.title(f'PV Energy Profile for date -{filedate}', fontdict = {'fontsize' : 15},color= 'blue', fontweight='bold')
plt.savefig('PV_2021.06.26.pdf')
plt.show();
# plt.savefig('PV_2021.06.26.pdf')

# %%
# Smooth Line

ax = plt.subplot(111)

ax.set_xlabel("Time_srt",fontsize=14)
ax.set_ylabel("KW/hr",color="red",fontsize=14)
ax.set_ylim([-5, 90])
l1 = ax.plot(ss, yeg, '-', label=f"Energy Generated - {Total_gen}", color='g')
l2 = ax.plot(ss, yec,'-', label=f"Energy Consumed - {Total_con}", color='lime')
l3 = ax.plot(ss, yee, '-', label=f"Energy Exported - {Total_exp}", color='b')
l4 = ax.plot(ss, yei, '-', label=f"Energy Imported - {Total_imp}", color='r')
# l5 = ax.plot(ss, yat, '-', label="Ambient Temperature")

ax2=ax.twinx()
l6 = ax2.plot(ss, ybs, '-', label = 'Battery %', color='darkviolet');
ax2.set_ylabel("Battery %",color="darkviolet",fontsize=14)
ax2.set_ylim([80, 105])

l = l1+l2+l3+l4+l6
labs = [ll.get_label() for ll in l]
ax.legend(l, labs, loc=2);

ax.grid();
plt.title(f'PV Energy Profile for date -{filedate}', fontdict = {'fontsize' : 15},color= 'blue', fontweight='bold')
plt.show();

# %%
# ax = df.plot(x_compat=True)
plt.plot(xec, yec, label="Energy Consumed")
plt.plot(xec, yeg, label="Energy Generated")
plt.plot(xec, yei, label="Energy Imported")
plt.plot(xec, yee, label="Energy Exported")
plt.plot(xec, yat, label="Ambient Temperature")

plt.xticks(np.arange(0, len(xec)+1, 2))

# plt.xticks(np.arange(0, len(xeg)+1, 4));
# plt.yticks(np.arange(0, max (yec), 1))
plt.legend();
plt.grid()
# Out:
# The history saving thread hit an unexpected error (OperationalError('database is locked')).History will not be written to the database.

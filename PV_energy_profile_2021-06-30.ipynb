# %%
import pandas as pd

# %%
import numpy as np

# %%
from datetime import datetime

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = [15, 5]

# %%
raw_data = pd.read_excel("H://Python_Projects_001//Test_PV//2021 06 30 0000 (Float).xlsx")
raw_data[12:32]
# Out:
#         ;Date      Time  Millitm  \
# 12 2021-06-30  00:00:00      552
# 13 2021-06-30  00:00:00      552
# 14 2021-06-30  00:00:00      552
# 15 2021-06-30  00:00:00      552
# 16 2021-06-30  00:00:00      552
# 17 2021-06-30  00:00:00      552
# 18 2021-06-30  00:00:00      552
# 19 2021-06-30  00:00:00      552
# 20 2021-06-30  00:00:00      552
# 21 2021-06-30  00:00:00      552
# 22 2021-06-30  00:00:00      552
# 23 2021-06-30  00:00:00      552
# 24 2021-06-30  00:00:00      552
# 25 2021-06-30  00:00:00      552
# 26 2021-06-30  00:00:00      552
# 27 2021-06-30  00:00:00      552
# 28 2021-06-30  00:00:00      552
# 29 2021-06-30  00:00:00      552
# 30 2021-06-30  00:00:00      552
# 31 2021-06-30  00:02:05      880
#
#                                               Tagname       Value Status  \
# 12  LOG\INVERTER_2_DC_POWER                       ...    0.000000
# 13  LOG\INVERTER_3_DC_POWER                       ...    0.000000
# 14  LOG\INVERTER_4_AC_POWER                       ...    0.000000
# 15  LOG\INVERTER_4_DC_POWER                       ...    0.000000
# 16  LOG\INVERTER_5_AC_POWER                       ...    0.000000
# 17  LOG\INVERTER_5_DC_POWER                       ...    0.000000
# 18  LOG\PRODUCTTRANSFERTRIP                       ...    0.000000
# 19  LOG\PV_MODULE_TEMPERATURE                     ...   30.000000
# 20  LOG\SOC_BATTERY_CLUSTER_1                     ...   99.000000
# 21  LOG\SOC_BATTERY_CLUSTER_2                     ...  100.000000
# 22  LOG\SOC_BATTERY_MAIN_CLUSTER                  ...  100.000000
# 23  LOG\SOLAR_IRRADIATION                         ...    0.000000
# 24  LOG\TOTAL_POWER                               ...    0.000000
# 25  LOG\VOLTAGE_OF_GRID_PHASE_1                   ...  222.198776
# 26  LOG\VOLTAGE_OF_GRID_PHASE_2                   ...  222.574387
# 27  LOG\VOLTAGE_OF_GRID_PHASE_3                   ...  222.168365
# 28  LOG\WIND_SPEED                                ...    0.000000
# 29  LOG\INVERTER_3_AC_POWER                       ...   26.569387
# 30  LOG\ENERGY_GENERATED                          ...  708.387817
# 31  LOG\AMBIENT_TEMPRATURE                        ...   32.099998
#
#    Marker  Internal
# 12      B        -1
# 13      B        -1
# 14      B        -1
# 15      B        -1
# 16      B        -1
# 17      B        -1
# 18      B        -1
# 19      B        -1
# 20      B        -1
# 21      B        -1
# 22      B        -1
# 23      B        -1
# 24      B        -1
# 25      B        -1
# 26      B        -1
# 27      B        -1
# 28      B        -1
# 29      B        -1
# 30      B        -1
# 31                0

# %%
# Important ----Remove whitspace befor and after string --- here Tagname----
raw_data['Tagname'] = raw_data['Tagname'].str.strip()

# %%
# Time column is in datetime formate to extract one hour time, Time column to be converted to string
raw_data['Time'][1]
# Out:
# datetime.time(0, 0)

# %%
# Converting datetime to string, use strftime('%H:%M:%S')
# ff - In datetime format
# ff1 - Converted to String format
ff = raw_data['Time'][425]
ff1 = ff.strftime('%H:%M:%S')
ff1
# Out:
# '01:02:05'

# %%
ff3 = raw_data['Time']
ff3
# Out:
# 0       00:00:00
# 1       00:00:00
# 2       00:00:00
# 3       00:00:00
# 4       00:00:00
#           ...
# 8985    00:00:00
# 8986    00:00:00
# 8987    00:00:00
# 8988    00:00:00
# 8989    00:00:00
# Name: Time, Length: 8990, dtype: object

# %%
ff4 = pd.to_datetime(ff3,format= '%H:%M:%S')
ff4
# Out:
# 0      1900-01-01
# 1      1900-01-01
# 2      1900-01-01
# 3      1900-01-01
# 4      1900-01-01
#           ...
# 8985   1900-01-01
# 8986   1900-01-01
# 8987   1900-01-01
# 8988   1900-01-01
# 8989   1900-01-01
# Name: Time, Length: 8990, dtype: datetime64[ns]

# %%
Time_hr = ff4.dt.time
Time_hr
# Out:
# 0       00:00:00
# 1       00:00:00
# 2       00:00:00
# 3       00:00:00
# 4       00:00:00
#           ...
# 8985    00:00:00
# 8986    00:00:00
# 8987    00:00:00
# 8988    00:00:00
# 8989    00:00:00
# Name: Time, Length: 8990, dtype: object

# %%
Time_hr_str = ff4.dt.strftime('%H:%M:%S')
Time_hr_str
# Out:
# 0       00:00:00
# 1       00:00:00
# 2       00:00:00
# 3       00:00:00
# 4       00:00:00
#           ...
# 8985    00:00:00
# 8986    00:00:00
# 8987    00:00:00
# 8988    00:00:00
# 8989    00:00:00
# Name: Time, Length: 8990, dtype: object

# %%
rd_df = raw_data.copy()

# %%
rd_df
# Out:
#           ;Date      Time  Millitm                      Tagname         Value  \
# 0    2021-06-30  00:00:00      552       LOG\AMBIENT_TEMPRATURE     32.099998
# 1    2021-06-30  00:00:00      552  LOG\ENERGY_CONSUMED_BY_LOAD    120.437195
# 2    2021-06-30  00:00:00      552   LOG\EVENT_FAULT_INVERTER_1  10863.000000
# 3    2021-06-30  00:00:00      552   LOG\EVENT_FAULT_INVERTER_2      0.000000
# 4    2021-06-30  00:00:00      552   LOG\EVENT_FAULT_INVERTER_3  13007.000000
# ...         ...       ...      ...                          ...           ...
# 8985 2021-07-01  00:00:00      693  LOG\VOLTAGE_OF_GRID_PHASE_2    225.607407
# 8986 2021-07-01  00:00:00      693  LOG\VOLTAGE_OF_GRID_PHASE_3    225.068710
# 8987 2021-07-01  00:00:00      693               LOG\WIND_SPEED      0.000000
# 8988 2021-07-01  00:00:00      693      LOG\INVERTER_3_AC_POWER     24.726820
# 8989 2021-07-01  00:00:00      693         LOG\ENERGY_GENERATED    708.918152
#
#      Status Marker  Internal
# 0                B        -1
# 1                B        -1
# 2                B        -1
# 3                B        -1
# 4                B        -1
# ...     ...    ...       ...
# 8985             E      8954
# 8986             E      8955
# 8987             E      8956
# 8988             E      8957
# 8989             E      8958
#
# [8990 rows x 8 columns]

# %%
rd_df.insert(2, "Time_srt",Time_hr_str )

# %%
rd_df
# Out:
#           ;Date      Time  Time_srt  Millitm                      Tagname  \
# 0    2021-06-30  00:00:00  00:00:00      552       LOG\AMBIENT_TEMPRATURE
# 1    2021-06-30  00:00:00  00:00:00      552  LOG\ENERGY_CONSUMED_BY_LOAD
# 2    2021-06-30  00:00:00  00:00:00      552   LOG\EVENT_FAULT_INVERTER_1
# 3    2021-06-30  00:00:00  00:00:00      552   LOG\EVENT_FAULT_INVERTER_2
# 4    2021-06-30  00:00:00  00:00:00      552   LOG\EVENT_FAULT_INVERTER_3
# ...         ...       ...       ...      ...                          ...
# 8985 2021-07-01  00:00:00  00:00:00      693  LOG\VOLTAGE_OF_GRID_PHASE_2
# 8986 2021-07-01  00:00:00  00:00:00      693  LOG\VOLTAGE_OF_GRID_PHASE_3
# 8987 2021-07-01  00:00:00  00:00:00      693               LOG\WIND_SPEED
# 8988 2021-07-01  00:00:00  00:00:00      693      LOG\INVERTER_3_AC_POWER
# 8989 2021-07-01  00:00:00  00:00:00      693         LOG\ENERGY_GENERATED
#
#              Value Status Marker  Internal
# 0        32.099998             B        -1
# 1       120.437195             B        -1
# 2     10863.000000             B        -1
# 3         0.000000             B        -1
# 4     13007.000000             B        -1
# ...            ...    ...    ...       ...
# 8985    225.607407             E      8954
# 8986    225.068710             E      8955
# 8987      0.000000             E      8956
# 8988     24.726820             E      8957
# 8989    708.918152             E      8958
#
# [8990 rows x 9 columns]

# %%
# Time_hr_str[]

# %%
# raw_data.shape

# %%
# raw_data.index

# %%
# raw_data['Tagname'] == 'LOG\ENERGY_GENERATED'

# %%
# raw_data[raw_data['Tagname'] == 'LOG\ENERGY_GENERATED']

# %%
# raw_data.tail(5)

# %%
# raw_data['Value']

# %%
# filtData = raw_data[raw_data["Tagname"] == 'LOG\ENERGY_GENERATED']

# %%
# filtData

# %%
#  filtData.reset_index(drop=True, inplace=True)

# %%
# filtData

# %%
# time_ts = pd.to_datetime(filtData["Time"].iloc[3], format='%H:%M:%S')

# %%
# time_ts

# %%
# onehr_ts = pd.date_range(time_ts, periods=24, freq='1h')
# onehr1 = onehr_ts.strftime('%H:%M:%S')

# %%
# rd_df[rd_df['Time_srt'] == onehr1[1]]

# %%
# raw_data['Time'][1].

# %%
# ff = raw_data['Time'][425]
# ff1 = ff.strftime('%H:%M:%S')

# %%
# ff1

# %%
# onehr1[1]

# %%
# ff1 == onehr1[1]

# %%
class Extracting_Para ():

    def __init__(self, Tagname):
        self.Tagname = Tagname
        
    def individual_df(self):
        ind_df = pd.DataFrame()
        filtData = rd_df[rd_df["Tagname"] == self.Tagname]
        filtData.reset_index(drop=True, inplace=True)
        time_ts = pd.to_datetime(filtData["Time"].iloc[1], format='%H:%M:%S')
        onehr_ts = pd.date_range(time_ts, periods=24, freq='1h')
        onehr1 = onehr_ts.strftime('%H:%M:%S')
        for x in range(0, len(filtData)):
            for y in onehr1:
                if(filtData["Time_srt"].iloc[x] == y):
                    c1 = filtData["Time_srt"] == y
                    Extract = filtData.loc[c1, [';Date', 'Time_srt', 'Tagname', 'Value']]
                    ind_df = ind_df.append(Extract)
        ind_df.reset_index(drop=True, inplace=True)
        ind_df1 = ind_df.copy()
        self.ind_df1 = ind_df1
        return ind_df

#     def onehr_df(self):
#         val = self.ind_df1
#         val1 = val["Value"]
#         onehr_val = np.diff(val1)*1000
#         onehr_val=np.insert(onehr_val,0,0)
#         val.insert(4, "KW/hr",  onehr_val)
#         return val

    def onehr_df(self):
        val = self.ind_df1
        val1 = val["Value"]
        onehr_val = np.diff(val1)*1000
        cpVal = onehr_val[1]
        onehr_val=np.insert(onehr_val,0,cpVal)
        val.insert(4, "KW/hr",  onehr_val)
        return val
    
    def total(self):
        onedf = self.ind_df1
        totalEg = (onedf.iloc[-1]['Value'] - onedf.iloc[0]['Value'])*1000
        totalVal = f'TOTAL_{self.Tagname[4:]} = {"{:.2f}".format(totalEg)} KW ' 
        return totalVal
#     def stri(self):
#         return self.Tagname[4:]
#     >>> print("{:.2f}".format(a))

# %%
energy_gen = Extracting_Para("LOG\ENERGY_GENERATED")
df_energy_gen = energy_gen.individual_df()
eng_gen_onehr = energy_gen.onehr_df()
Total_gen = energy_gen.total()
# sss = energy_gen.stri()

# %%
Total_gen
# Out:
# 'TOTAL_ENERGY_GENERATED = 530.33 KW '

# %%
df_energy_gen
# Out:
#         ;Date  Time_srt               Tagname       Value
# 0  2021-06-30  00:02:05  LOG\ENERGY_GENERATED  708.387817
# 1  2021-06-30  01:02:05  LOG\ENERGY_GENERATED  708.387817
# 2  2021-06-30  02:02:05  LOG\ENERGY_GENERATED  708.387817
# 3  2021-06-30  03:02:05  LOG\ENERGY_GENERATED  708.387817
# 4  2021-06-30  04:02:05  LOG\ENERGY_GENERATED  708.387817
# 5  2021-06-30  05:02:05  LOG\ENERGY_GENERATED  708.387817
# 6  2021-06-30  06:02:05  LOG\ENERGY_GENERATED  708.387817
# 7  2021-06-30  07:02:05  LOG\ENERGY_GENERATED  708.391357
# 8  2021-06-30  08:02:05  LOG\ENERGY_GENERATED  708.406128
# 9  2021-06-30  09:02:05  LOG\ENERGY_GENERATED  708.438416
# 10 2021-06-30  10:02:05  LOG\ENERGY_GENERATED  708.487000
# 11 2021-06-30  11:02:05  LOG\ENERGY_GENERATED  708.549316
# 12 2021-06-30  12:02:05  LOG\ENERGY_GENERATED  708.614319
# 13 2021-06-30  13:02:05  LOG\ENERGY_GENERATED  708.683777
# 14 2021-06-30  14:02:05  LOG\ENERGY_GENERATED  708.750427
# 15 2021-06-30  15:02:05  LOG\ENERGY_GENERATED  708.810242
# 16 2021-06-30  16:02:05  LOG\ENERGY_GENERATED  708.860107
# 17 2021-06-30  17:02:05  LOG\ENERGY_GENERATED  708.895386
# 18 2021-06-30  18:02:05  LOG\ENERGY_GENERATED  708.912903
# 19 2021-06-30  19:02:05  LOG\ENERGY_GENERATED  708.917786
# 20 2021-06-30  20:02:05  LOG\ENERGY_GENERATED  708.918152
# 21 2021-06-30  21:02:05  LOG\ENERGY_GENERATED  708.918152
# 22 2021-06-30  22:02:05  LOG\ENERGY_GENERATED  708.918152
# 23 2021-06-30  23:02:05  LOG\ENERGY_GENERATED  708.918152

# %%
eng_gen_onehr.head()
# Out:
#        ;Date  Time_srt               Tagname       Value  KW/hr
# 0 2021-06-30  00:02:05  LOG\ENERGY_GENERATED  708.387817    0.0
# 1 2021-06-30  01:02:05  LOG\ENERGY_GENERATED  708.387817    0.0
# 2 2021-06-30  02:02:05  LOG\ENERGY_GENERATED  708.387817    0.0
# 3 2021-06-30  03:02:05  LOG\ENERGY_GENERATED  708.387817    0.0
# 4 2021-06-30  04:02:05  LOG\ENERGY_GENERATED  708.387817    0.0

# %%
(eng_gen_onehr.iloc[-1]['Value'] - eng_gen_onehr.iloc[-0]['Value'])*1000
# Out:
# 530.334479999965

# %%
sum(eng_gen_onehr["KW/hr"])
# Out:
# 530.334479999965

# %%
len(eng_gen_onehr)
# Out:
# 24

# %%
energy_exp = Extracting_Para("LOG\EXPORTED_ENERGY_TO_GRID")
df_energy_exp = energy_exp.individual_df()
eng_exp_onehr = energy_exp.onehr_df()
Total_exp = energy_exp.total()

# %%
eng_exp_onehr.head()
# Out:
#        ;Date  Time_srt                      Tagname       Value  KW/hr
# 0 2021-06-30  00:02:05  LOG\EXPORTED_ENERGY_TO_GRID  527.549622    0.0
# 1 2021-06-30  01:02:05  LOG\EXPORTED_ENERGY_TO_GRID  527.549622    0.0
# 2 2021-06-30  02:02:05  LOG\EXPORTED_ENERGY_TO_GRID  527.549622    0.0
# 3 2021-06-30  03:02:05  LOG\EXPORTED_ENERGY_TO_GRID  527.549622    0.0
# 4 2021-06-30  04:02:05  LOG\EXPORTED_ENERGY_TO_GRID  527.549622    0.0

# %%
Total_exp
# Out:
# 'TOTAL_EXPORTED_ENERGY_TO_GRID = 450.32 KW '

# %%
energy_imp = Extracting_Para("LOG\IMPORTED_ENERGY_TO_GRID")
df_energy_imp = energy_imp.individual_df()
energy_imp_onehr = energy_imp.onehr_df()
Total_imp = energy_imp.total()

# %%
energy_imp_onehr.head()
# Out:
#        ;Date  Time_srt                      Tagname     Value    KW/hr
# 0 2021-06-30  00:02:05  LOG\IMPORTED_ENERGY_TO_GRID  7.269289  0.04387
# 1 2021-06-30  01:02:05  LOG\IMPORTED_ENERGY_TO_GRID  7.269332  0.04244
# 2 2021-06-30  02:02:05  LOG\IMPORTED_ENERGY_TO_GRID  7.269376  0.04387
# 3 2021-06-30  03:02:05  LOG\IMPORTED_ENERGY_TO_GRID  7.269423  0.04673
# 4 2021-06-30  04:02:05  LOG\IMPORTED_ENERGY_TO_GRID  7.269476  0.05341

# %%
Total_imp
# Out:
# 'TOTAL_IMPORTED_ENERGY_TO_GRID = 1.21 KW '

# %%
energy_con = Extracting_Para("LOG\ENERGY_CONSUMED_BY_LOAD")
df_energy_con = energy_con.individual_df()
energy_con_onehr = energy_con.onehr_df()
Total_con = energy_con.total()

# %%
energy_con_onehr.head()
# Out:
#        ;Date  Time_srt                      Tagname       Value    KW/hr
# 0 2021-06-30  00:02:05  LOG\ENERGY_CONSUMED_BY_LOAD  120.437195  0.08392
# 1 2021-06-30  01:02:05  LOG\ENERGY_CONSUMED_BY_LOAD  120.437279  0.08393
# 2 2021-06-30  02:02:05  LOG\ENERGY_CONSUMED_BY_LOAD  120.437363  0.08392
# 3 2021-06-30  03:02:05  LOG\ENERGY_CONSUMED_BY_LOAD  120.437447  0.08392
# 4 2021-06-30  04:02:05  LOG\ENERGY_CONSUMED_BY_LOAD  120.437546  0.09919

# %%
Total_con
# Out:
# 'TOTAL_ENERGY_CONSUMED_BY_LOAD = 87.23 KW '

# %%
energy_con_onehr['Time_srt'].head()
# Out:
# 0    00:02:05
# 1    01:02:05
# 2    02:02:05
# 3    03:02:05
# 4    04:02:05
# Name: Time_srt, dtype: object

# %%
amp_temp = Extracting_Para("LOG\AMBIENT_TEMPRATURE")
at = amp_temp.individual_df()
# energy_con_onehr = energy_con.onehr_df()

# %%
at
# Out:
#         ;Date  Time_srt                 Tagname      Value
# 0  2021-06-30  00:02:05  LOG\AMBIENT_TEMPRATURE  32.099998
# 1  2021-06-30  01:02:05  LOG\AMBIENT_TEMPRATURE  31.900000
# 2  2021-06-30  02:02:05  LOG\AMBIENT_TEMPRATURE  30.700001
# 3  2021-06-30  03:02:05  LOG\AMBIENT_TEMPRATURE  30.400000
# 4  2021-06-30  04:02:05  LOG\AMBIENT_TEMPRATURE  30.500000
# 5  2021-06-30  05:02:05  LOG\AMBIENT_TEMPRATURE  31.299999
# 6  2021-06-30  06:02:05  LOG\AMBIENT_TEMPRATURE  30.799999
# 7  2021-06-30  07:02:05  LOG\AMBIENT_TEMPRATURE  33.599998
# 8  2021-06-30  08:02:05  LOG\AMBIENT_TEMPRATURE  35.900002
# 9  2021-06-30  09:02:05  LOG\AMBIENT_TEMPRATURE  38.000000
# 10 2021-06-30  10:02:05  LOG\AMBIENT_TEMPRATURE  39.000000
# 11 2021-06-30  11:02:05  LOG\AMBIENT_TEMPRATURE  40.700001
# 12 2021-06-30  12:02:05  LOG\AMBIENT_TEMPRATURE  41.400002
# 13 2021-06-30  13:02:05  LOG\AMBIENT_TEMPRATURE  43.299999
# 14 2021-06-30  14:02:05  LOG\AMBIENT_TEMPRATURE  43.599998
# 15 2021-06-30  15:02:05  LOG\AMBIENT_TEMPRATURE  42.000000
# 16 2021-06-30  16:02:05  LOG\AMBIENT_TEMPRATURE  41.000000
# 17 2021-06-30  17:02:05  LOG\AMBIENT_TEMPRATURE  39.400002
# 18 2021-06-30  18:02:05  LOG\AMBIENT_TEMPRATURE  38.299999
# 19 2021-06-30  19:02:05  LOG\AMBIENT_TEMPRATURE  37.200001
# 20 2021-06-30  20:02:05  LOG\AMBIENT_TEMPRATURE  35.799999
# 21 2021-06-30  21:02:05  LOG\AMBIENT_TEMPRATURE  33.500000
# 22 2021-06-30  22:02:05  LOG\AMBIENT_TEMPRATURE  32.000000
# 23 2021-06-30  23:02:05  LOG\AMBIENT_TEMPRATURE  30.600000

# %%
s = at['Time_srt']

# %%
ss = s.str.slice(stop = 5)

# %%
ss.head()
# Out:
# 0    00:02
# 1    01:02
# 2    02:02
# 3    03:02
# 4    04:02
# Name: Time_srt, dtype: object

# %%
batt = Extracting_Para("LOG\SOC_BATTERY_MAIN_CLUSTER")
batt_st = batt.individual_df()
# energy_con_onehr = energy_con.onehr_df()
# LOG\SOC_BATTERY_MAIN_CLUSTER

# %%
batt_st
# Out:
#         ;Date  Time_srt                       Tagname  Value
# 0  2021-06-30  00:02:05  LOG\SOC_BATTERY_MAIN_CLUSTER  100.0
# 1  2021-06-30  01:02:05  LOG\SOC_BATTERY_MAIN_CLUSTER  100.0
# 2  2021-06-30  02:02:05  LOG\SOC_BATTERY_MAIN_CLUSTER  100.0
# 3  2021-06-30  03:02:05  LOG\SOC_BATTERY_MAIN_CLUSTER  100.0
# 4  2021-06-30  04:02:05  LOG\SOC_BATTERY_MAIN_CLUSTER  100.0
# 5  2021-06-30  05:02:05  LOG\SOC_BATTERY_MAIN_CLUSTER  100.0
# 6  2021-06-30  06:02:05  LOG\SOC_BATTERY_MAIN_CLUSTER  100.0
# 7  2021-06-30  07:02:05  LOG\SOC_BATTERY_MAIN_CLUSTER  100.0
# 8  2021-06-30  08:02:05  LOG\SOC_BATTERY_MAIN_CLUSTER  100.0
# 9  2021-06-30  09:02:05  LOG\SOC_BATTERY_MAIN_CLUSTER  100.0
# 10 2021-06-30  10:02:05  LOG\SOC_BATTERY_MAIN_CLUSTER  100.0
# 11 2021-06-30  11:02:05  LOG\SOC_BATTERY_MAIN_CLUSTER  100.0
# 12 2021-06-30  12:02:05  LOG\SOC_BATTERY_MAIN_CLUSTER  100.0
# 13 2021-06-30  13:02:05  LOG\SOC_BATTERY_MAIN_CLUSTER  100.0
# 14 2021-06-30  14:02:05  LOG\SOC_BATTERY_MAIN_CLUSTER  100.0
# 15 2021-06-30  15:02:05  LOG\SOC_BATTERY_MAIN_CLUSTER  100.0
# 16 2021-06-30  16:02:05  LOG\SOC_BATTERY_MAIN_CLUSTER  100.0
# 17 2021-06-30  17:02:05  LOG\SOC_BATTERY_MAIN_CLUSTER  100.0
# 18 2021-06-30  18:02:05  LOG\SOC_BATTERY_MAIN_CLUSTER  100.0
# 19 2021-06-30  19:02:05  LOG\SOC_BATTERY_MAIN_CLUSTER   99.0
# 20 2021-06-30  20:02:05  LOG\SOC_BATTERY_MAIN_CLUSTER   98.0
# 21 2021-06-30  21:02:05  LOG\SOC_BATTERY_MAIN_CLUSTER   98.0
# 22 2021-06-30  22:02:05  LOG\SOC_BATTERY_MAIN_CLUSTER   97.0
# 23 2021-06-30  23:02:05  LOG\SOC_BATTERY_MAIN_CLUSTER   96.0

# %%
xec = energy_con_onehr['Time_srt']
yec = energy_con_onehr['KW/hr']
xei = energy_imp_onehr['Time_srt']
yei = energy_imp_onehr['KW/hr']
xeg = eng_gen_onehr['Time_srt']
yeg = eng_gen_onehr['KW/hr']
xee = eng_exp_onehr['Time_srt']
yee = eng_exp_onehr['KW/hr']
xat = at['Time_srt']
yat = at['Value']
ybs = batt_st['Value']

# %%
# plt.plot([0.1, 0.2, 0.3, 0.4], [1, 2, 3, 4])
# plt.plot([0.1, 0.2, 0.3, 0.4], [1, 4, 9, 16])
# plt.xlabel("Time (s)")
# plt.ylabel("Scale (Bananas)")

# %%
xec.to_numpy;
yec.to_numpy;
xeg.to_numpy;
yeg.to_numpy;
xei.to_numpy;
yei.to_numpy;
xee.to_numpy;
yee.to_numpy;
xat.to_numpy;
yat.to_numpy;
ybs.to_numpy;

# %%
rd_df[';Date'][1]
# Out:
# Timestamp('2021-06-30 00:00:00')

# %%
date = rd_df[';Date'][1].date()

# %%
filedate = date.strftime("%Y/%m/%d")

# %%
ss.head()
# Out:
# 0    00:02
# 1    01:02
# 2    02:02
# 3    03:02
# 4    04:02
# Name: Time_srt, dtype: object

# %%
# ax = df.plot(x_compat=True)
plt.plot(ss, yec, label="Energy Consumed")
plt.plot(ss, yeg, label="Energy Generated")
plt.plot(ss, yei, label="Energy Imported")
plt.plot(ss, yee, label="Energy Exported")
plt.plot(ss, yat, label="Ambient Temperature")

plt.plot(ss, ybs, label="Battery Status")

plt.xticks(np.arange(0, len(ss), 1))

# plt.xticks(np.arange(0, len(xeg)+1, 4));
# plt.yticks(np.arange(0, max (yec), 1))
plt.legend();
plt.grid()

# %%
# ax = df.plot(x_compat=True)
# %matplotlib inline
ax = plt.subplot(111)


ax.set_xlabel("Time_srt",fontsize=14)
ax.set_ylabel("KW/hr",color="red",fontsize=14)


l1 = ax.plot(ss, yeg, '-', label="Energy Generated")
l2 = ax.plot(ss, yec,'-', label="Energy Consumed")
l3 = ax.plot(ss, yee, '-', label="Energy Exported")
l4 = ax.plot(ss, yei, '-', label="Energy Imported")
# l5 = ax.plot(ss, yat, '-', label="Ambient Temperature")

ax2=ax.twinx()
l6 = ax2.plot(ss, ybs, '-', label = 'Battery %', color='b');
ax2.set_ylabel("Battery %",color="blue",fontsize=14)

l = l1+l2+l3+l4+l6
labs = [ll.get_label() for ll in l]
ax.legend(l, labs, loc=2);
# plt.xticks(np.arange(0, len(ss), 1))

# plt.xticks(np.arange(0, len(xeg)+1, 4));
# plt.yticks(np.arange(0, max (yec), 1))
# plt.legend();
ax.grid();
plt.title(f'PV Energy Profile for date -{filedate}', fontdict = {'fontsize' : 15},color= 'blue', fontweight='bold')
plt.show();

# %%
# Adding Total value in the Legend - Task completed

ax = plt.subplot(111)

ax.set_xlabel("Time_srt",fontsize=14)
ax.set_ylabel("KW/hr",color="red",fontsize=14)

l1 = ax.plot(ss, yeg, '-', label=f"Energy Generated - {Total_gen}", color='g')
l2 = ax.plot(ss, yec,'-', label=f"Energy Consumed - {Total_con}", color='lime')
l3 = ax.plot(ss, yee, '-', label=f"Energy Exported - {Total_exp}", color='b')
l4 = ax.plot(ss, yei, '-', label=f"Energy Imported - {Total_imp}", color='r')
# l5 = ax.plot(ss, yat, '-', label="Ambient Temperature")

ax2=ax.twinx()
l6 = ax2.plot(ss, ybs, '-', label = 'Battery %', color='darkviolet');
ax2.set_ylabel("Battery %",color="darkviolet",fontsize=14)
ax2.set_ylim([70, 105])

l = l1+l2+l3+l4+l6
labs = [ll.get_label() for ll in l]
ax.legend(l, labs, loc=2);

ax.grid();
plt.title(f'PV Energy Profile for date -{filedate}', fontdict = {'fontsize' : 15},color= 'blue', fontweight='bold')
plt.savefig('PV_2021.06.30.pdf')
plt.show();

# %%
# Smooth Line

ax = plt.subplot(111)

ax.set_xlabel("Time_srt",fontsize=14)
ax.set_ylabel("KW/hr",color="red",fontsize=14)
ax.set_ylim([-5, 90])
l1 = ax.plot(ss, yeg, '-', label=f"Energy Generated - {Total_gen}", color='g')
l2 = ax.plot(ss, yec,'-', label=f"Energy Consumed - {Total_con}", color='lime')
l3 = ax.plot(ss, yee, '-', label=f"Energy Exported - {Total_exp}", color='b')
l4 = ax.plot(ss, yei, '-', label=f"Energy Imported - {Total_imp}", color='r')
# l5 = ax.plot(ss, yat, '-', label="Ambient Temperature")

ax2=ax.twinx()
l6 = ax2.plot(ss, ybs, '-', label = 'Battery %', color='darkviolet');
ax2.set_ylabel("Battery %",color="darkviolet",fontsize=14)
ax2.set_ylim([80, 105])

l = l1+l2+l3+l4+l6
labs = [ll.get_label() for ll in l]
ax.legend(l, labs, loc=2);

ax.grid();
plt.title(f'PV Energy Profile for date -{filedate}', fontdict = {'fontsize' : 15},color= 'blue', fontweight='bold')
plt.show();

# %%
# ax = df.plot(x_compat=True)
plt.plot(xec, yec, label="Energy Consumed")
plt.plot(xec, yeg, label="Energy Generated")
plt.plot(xec, yei, label="Energy Imported")
plt.plot(xec, yee, label="Energy Exported")
plt.plot(xec, yat, label="Ambient Temperature")

plt.xticks(np.arange(0, len(xec)+1, 2))

# plt.xticks(np.arange(0, len(xeg)+1, 4));
# plt.yticks(np.arange(0, max (yec), 1))
plt.legend();
plt.grid()
